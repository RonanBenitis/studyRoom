# %% [markdown]
# # <span style="color: #87BBA2">===   Git e GitHub: repositório, commit e versões   ===</span>
#
# ## <span style="color: #87BBA2">01. Conta no Github</span>
#
# ### CONTA NO GITHUB
# **Termos**
# - Markdown: Linguagem simples de marcação utilizado na documentação do readme (.md). Esta documentação aceita, também, tags html.
# - Repositório: Pasta de armazenamento onde se está aplicando o controle de versionamento Git;
# - Commit: Rótulo das alterações que se está fazendo, sendo o momento exato de como está o projeto;
#   - Para inserirmos o readme foi necessário realizar um commit (inicial)
#   - Um commit guarda o estado do seu projeto naquele momento mas não o envia. Para enviá-lo, seria push.
#   - Na real, primeiro adicionamos os unstaged (ou adicionamos as modificões dos stageds), após a adição, nós commitamos (confirmação das alterações) e então o empurramos para o repositório (push).
#
# ### ÓTIMAS DICAS E ORIENTAÇÕES PARA README
# [Link](https://www.alura.com.br/artigos/escrever-bom-readme)

# %% [markdown]
# ## <span style="color: #87BBA2">02. Commit, VSCode e equipe</span>
#
# ### VSCode no GitHub
# Na pagina inicial dentro de um repositório de sua autoria (ou que você tenha permissão), aperte a tecla `.`. Este é o atalho para abrir o **VSCode Web (VSCode na Núvem)** com a estrutura do projeto no commit mais recente da branch que que você está.
#
# Todas as alterações que estão feitas no **VSCode Web** estão sendo "escutadas" pelo GitHub, aparecendo, no simbolo das "branchs" no menu lateral um número indicando quantas alterações no projeto aconteceram (seja criação ou edição de código). Porém, as alterações estão sendo rastreadas mas só subirão para o repositório quando realizarmos o **commit**.
#
# Para commitar, vá no simbolo das branchs, escreva a mensagem de commit na caixinha e **clique no simbolo de correto** (Mas, agora tem um botãozão também).

# %% [markdown]
# ## <span style="color: #87BBA2">03. Trabalhando localmente</span>
#
# ### Git clone e log
# Criador do Git = Linus Torvalds
#
# #### O que é o GIT
# - Git é um sistema de controle versões distribuido;
# - Desenvolvimento distribuido
#   - A versão que está na minha maquina, quando baixar o projeto, será a mesma que está na sua, inclusive seu histórico.
# - Git x GitHub = Git é o sistema, GitHub é sua utilização e armazenamento na Web. Além do GitHub, existe GitLab dentro outros.
#
# #### git clone
# - [git clone documentação oficial](https://git-scm.com/docs/git-clone)
# - [mais informações de git clone by Alura](https://cursos.alura.com.br/course/git-github-repositorio-commit-versoes/task/106571)
# - Indo no GitHub e em Code, copiamos o HTTPS do projeto.
# - No terminal, em qualquer terminal (Seja no Bash, no Powershell e afins).
# - Com o terminal (através dos comandos `cd`), navegue para a pasta desejada e escreva o seguinte comando, quando estiver na pasta:
# ```JAVASCRIPT
# git clone <link>
# ```
# - Clone realizado
#
# #### git log
# - [git log cheatsheet](https://devhints.io/git-log)
# - [Mais comandos gitlog by Alura](https://cursos.alura.com.br/course/git-github-repositorio-commit-versoes/task/106997)
# - Acesse a pasta com que está sendo controlada por git
# - No terminal:
# ```JAVASCRIPT
# // Relatório dos commits recentes
# // Retorna relatório completo do commit
# git log
# // Relatório de todos os commits já feitos (uma linha por commit)
# // Retorna hash do commit seguido do comentario
# git log --oneline
# ```

# %% [markdown]
# ### Git status, commit e push
#
# Importante ter o código que está no GitHub, o que você está trabalhando, também em sua máquina, pois, como o Git é um sistema distribuido, ele garantirá que o código que está no repositório remoto seja o mesmo que esteja em sua maquina local.
#
# Por isso é importante saber comandos de linha.
#
# Neste momento, quando se está trabalhando localmente, que conheceremos o `push`, que é o **empurrar o que se está localmente para o remoto**. Quando trabalhamos diretamente na web, não tem essa necessidade pois seria meio que trabalhar na raiz do projeto.
#
# #### git pull
# Diferente do `git clone`, que apaga TUDO o que você tem e deposita o repositório onde você clonou, o `git pull`.
#
# O `git clone` só se faz para no inicio do projeto, quando se está montando o ambiente local.
#
# ```JAVASCRIPT
# // Na pasta local administrada por git, no terminal
# git pull <link>
# ```
#
# Retornos:
# - Already up to date: Código local em dia com o código no repositório remoto.
#
# #### git status
# Verifica o estado atual do código local: Se há alterações feitas e quais foram essas alterações (criação, modificação, deleção).
#
# #### git commit
# Comando em terminal, dentro de um ambiente local controlado por git, para realizar o commit das informações previamente adicionadas ou adicionar e commitar juntamente.
# ```JAVASCRIPT
# // Adicionando e commitando juntos
# git commit <arquivo_modificado_ou_criado> -m "<mensagem>"
# // Pra adicionar e commitar todas as alterações
# git commit . -m "<mesangem>"
# ```
#
# #### git push
# Seguindo todos os passos anteriores, atualizamos nosso projeto localmente mas não remotamente. Para "empurrarmos" até o repositório local nós usamos os `git push`.
# ```JAVASCRIPT
# // Empurrando para a origem
# git push origin main
# ```
# Ao realizar esse teste em algum repositório publico, você deve ter enfrentado algum erro. O `git clone` pode ser realizado de qualquer repositório remoto, mas, o `git push` só pode em repositórios onde somos autores ou colaboradores e, além disso, já termos configurado, corretamente, nossos parametros de git em nosso computador.
#
# Basicamente, esses parametros - que ficam em um arquivo de configuração, como sua chave pública e chave primaria - são configurados que se faz uma vez por máquina para gerar sua chave para o gitHub saber quem é a pessoa que está realizando o push, e, com isso, validar se ela pode ou não ter acesso ao repositório o qual busca-se dar o push e realizar seu registro.
# > É uma forma de fazermos o handshake e, assim, realizar a operação.
# >
# > Isso não é realizado no repositório remoto pois no remoto o acesso já está validado, já no local não, aí, isso que estamos fazendo é justamente configurar nossa chave de acesso do repositório local para o remoto.

# %% [markdown]
# ### O que vimos até aqui
#
# DIFF = A tela de antes e a tela depois de um commit realizado. É o `diff` de um commit, a diferença entre sua versão anterior e a versão atual.
#
# Repare que nosso `git pull` e `git push` não está sendo necessario colocar url, pois já temos nosso repositório local configurado com o remoto e não há mais ramificações além da principal (main).
#
# #### Voltando commits
# Para não precisar passar por cima dos commits, ou seja, dando ctrl+c e ctrl+v e dando um novo commit, o Git possibilita retornarmos a commits anteriores.
#
# Para fazer tudo em linha de comandos:
# ```JAVASCRIPT
# git log --oneline
#
# // relatório de hash e comentarios dos commits
#
# // Caso queira retornar a versão de um arquivo específico
# git restore --source <hash_do_commit> <nome_arquivo>
# ```
# ```JAVASCRIPT
# // Caso queira retornar a versão de todos os arquivos
# // para uma versão específica
# git restore --source <hash_do_commit> .
# ```
#
# Em seguida, demos o `git push` e não funcionou! Não funcinou pois realizamos as alterações e não as commitamos (não criamos seu rótulo).
#
# Commitamos o restart e demos o `git push` e agora sim a operação foi realizada em nosso repositório remoto.
#
# Precisamos deixar nosso repositório local pronto e limpo para enviar ao remoto, o local **nunca pode estar atrás** do remoto e, sim, **à frente**, pois, quando estamos o local está à frente aí sim podemos dar o commit.

# %% [markdown]
# ## <span style="color: #87BBA2">04. Adicionando arquivos</span>
#
# ### git add
# Essa é uma etapa antes do commit, usada para preparar os arquivos que não estavam sendo rastreado (unstaged). Sem essa adição, o git não rastreia seu versionamento.
#
# Caso tenha alguma alteração, o ideal é adicionar o arquivo com alteração desejado, ou todos os arquivos, e em seguida realizar a mesma operação mas com commit.
#
# Caso queira atualizar aquivo(s) específico(s) com alteração:
# ```JAVASCRIPT
# // Verifica se o repositório local possui alguma mudança frente ao remoto
# git status
# // Tem alguma alteração que está na frente do remoto? Adicionando arquivos
# git add <arquivo_especifico_alterado>
# // Comitando o arquivo adicionado
# git commit <arquivo_especifico_adicionado> -m "<mensagem>"
# // Empurrando para o repositório remoto
# git push
# ```
#
# Caso queira atualizar todos os aquivos específicos com alteração:
# ```JAVASCRIPT
# // Verifica se o repositório local possui alguma mudança frente ao remoto
# git status
# // Tem alguma alteração que está na frente do remoto? Adicionando arquivos
# git add .
# // Comitando o arquivo adicionado
# git commit -m "<mensagem>"
# // Empurrando para o repositório remoto
# git push
# ```
#
# **Importante**: Caso for commitar tudo sem dar add antes, só será commitado o arquivo que já está sendo rastreado (staged) e foi modificado. Os arquivos não rastreados (unstaged) permanecerão sem rastreio até o momento que darmos `git add`

# %% [markdown]
# ## <span style="color: #87BBA2">04. Ramificação e merge</span>
#
# ### BRANCH
# Branch são ramificações da aplicação/projeto, são os locais de desenvolvimento que parte do código principal mas correm paralelamente a ele, não intervindo no código principal até a completude do desenvolvimento dessa ramificação.
#
# #### CRIANDO BRANCH
# ```JAVASCRIPT
# // Comando para sair de uma branch, criar outra branch e acessá-la
# git checkout -b <nome_da_branch>
# // Ou, se for só criar a branch
# git branch <nome_da_branch>
# ```
# #### MUNDANDO DE BRANCH
# ```JAVASCRIPT
# // Pra mudar de branch, mas acho que o comando switch está ultrapassado
# git switch main
# ```
# #### COMMITANDO E PUSHANDO NA NOVA BRANCH
# ```JAVASCRIPT
# // Muda para a nova branch
# git switch <nome_da_branch_nova>
# // Adiciona os arquivos
# git add <nome_arquivo_alterado_ou_use_.>
# // Comittando
# git commit <arquivo_ou_ponto> -m "<mensagem>"
# // Pushando para uma nova origem
# git commit origin <nome_da_branch_nova>
# ```

# %% [markdown]
# ### MERGE
# Quando gostariamos de mesclar duas branchs, ou seja, pegar a nova branch e mesclar com a branch principal. Isso se chama merge.
# ```JAVASCRIPT
# // Lista todas as branchs do projeto
# git branch
# ```
# Para realizar o merge, precisamos estar na branch que receberá a mesclagem e chamar a branch que irá mesclar.
# ```JAVASCRIPT
# // Consideremos que nós estamos na main
#
# // Mergeando
# git merge <nome_da_branch_nova>
# ```
#
# Usando o `git log --oneline` antes e depois do merge, conseguimos observar que o merge cria um id novo, como se fosse um commit. Após o merge realizado, damos o `git push` para empurrar a operação para o repositório remoto.
#
# **Detalhe**, o `git push` deverá ter origem na branch desejada
# ```JAVASCRIPT
# // Empurrando alterações para a branch desejada
# git push origin main
# ```
#
# Quando realizamos o merge, na realidade, estamos dizendo para tanto na branch que recebeu o merge quanto a branch que realizou o merge apontem para o mesmo destino, e para isso, ambas as branchs precisam estar identicas (e aí entra a compatibilização).

# %% [markdown]
# ## CONCLUSÃO E LINKS
#
# - [Apanhadão de Git e Github da Alura, muito bom](https://www.alura.com.br/artigos/o-que-e-git-github), tendo a explicação do que é Git, GitHub, principais comandos, sequência de projeto (creio eu) e etc.
#
# ### COMANDOS PRINCIPAIS
# - git add . : Para adicionar todas as modificações realizadas de uma só vez;
# - git commit -m “mensagem do commit” : usado quando queremos capturar e salvar o estado atual do repositório;
# - git status: serve para listar todos os arquivos que foram modificados;
# - git push: utilizado para envio das alterações gravadas no diretório local para o repositório remoto. É utilizado para atualizar o repositório remoto com os commits feitos no repositório local;
# - git restore: trabalha com a restauração de arquivos e do projeto, voltando para um estado anterior através;
# - git log: exibe o histórico de commits do repositório. Mostra informações como o autor do commit, data, hora e mensagem associada a cada commit;
# - git log --oneline : mostra o log de forma resumida, em apenas uma linha;
# - git clone: clona um repositório para o seu ambiente local. É utilizado para obter uma cópia completa do repositório, incluindo todos os arquivos e histórico de commits. É utilizado quando você deseja obter uma cópia completa de um repositório remoto para começar um novo projeto ou colaborar com um projeto existente;
# - git branch: cria, lista ou exclui branches. Um branch é uma ramificação do histórico de commits, permitindo trabalhar em paralelo em diferentes versões do projeto;
# - git checkout: altera o branch atual ou restaura arquivos. É utilizado para alternar entre branches existentes ou restaurar arquivos para uma versão anterior. Atenção: é um comando que tem mais de uma função, se você quiser apenas trocar de branch sem alterar modificações, você pode utilizar o git switch;
# - git checkout -b “informe_o_nome_da_branch”: Cria uma nova branch e muda para ela;
# - git switch “nome_da_branch”: troca de uma branch para outra sem realizar alterações de estado. Observação: comando ainda em fase de experimentação;
# - git merge: mescla alterações de um branch para outro. É utilizado para combinar as alterações feitas em um branch com outro, integrando as modificações;
# - git pull: atualiza o repositório local com as alterações do repositório remoto. Quando você já possui uma cópia do repositório em seu computador e deseja trazer as últimas alterações feitas por outros colaboradores para sincronizá-las com seu repositório local. É diferente do git clone, que faz um clone do repositório remoto na sua máquina.
# - git fetch: busca as alterações do repositório remoto, mas não as mescla com o branch atual. É para obter informações mais recentes do repositório e verificar se há mudanças. Diferente do git pull , que já copia as alterações do repositório remoto;
# - git diff: mostra as diferenças entre arquivos ou commits;
# - git reset: desfaz commits ou altera o estado do repositório;
# - git remote: gerencia repositórios remotos;
